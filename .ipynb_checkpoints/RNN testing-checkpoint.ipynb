# %%
from scripts import preprocessing_old
from scripts import predict_stromfluss
from scripts import preprocessing_weatherdata
from scripts import preprocessing_plannedProduction
from scripts import preprocessing_trade_price_consumption
from bda import bda_utilities
import pandas as pd
import numpy as np

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Load and format power flow.

# %%
df = predict_stromfluss.read_data_stromfluss('./data/stromfluss')
df = predict_stromfluss.preprocessing_stromfluss(df)

# %%
def create_net_columns(df):
    countries = ["NL", "CHE", "DNK", "CZE", "LUX", "SWE", "AUT", "FRA", "PL"]
    for country in countries:
        im_key = country + "_IM"
        ex_key = country + "_EX"
        df[country]=df[im_key] +df[ex_key]
        df = df.drop(columns=[im_key,ex_key])
    return df

# %%
df = create_net_columns(df)
df = df.rename(columns={"Date":"date"})
df.head()
# Out:
#                  date      NX      NL    CHE    DNK    CZE  LUX  SWE     AUT  \
# 0 2015-06-01 00:00:00  7279.0  3932.0  145.0 -272.0  554.0  0.0  1.0  1394.0
# 1 2015-06-01 01:00:00  7167.0  4014.0  261.0 -141.0  469.0  0.0  1.0  1355.0
# 2 2015-06-01 02:00:00  6667.0  3864.0  103.0 -326.0  422.0  0.0  1.0  1574.0
# 3 2015-06-01 03:00:00  6413.0  4242.0   42.0 -262.0  235.0  0.0  1.0  1271.0
# 4 2015-06-01 04:00:00  5347.0  4292.0 -127.0 -582.0  161.0  0.0  1.0  1068.0
#
#      FRA      PL
# 0  246.0  1279.0
# 1   66.0  1142.0
# 2 -105.0  1134.0
# 3 -206.0  1090.0
# 4 -549.0  1083.0

# %% [markdown]
# Load and format weather data.

# %%
df_weather = preprocessing_weatherdata.import_weatherData()
df_weather = df_weather[df_weather['date'].dt.year >= 2015]
df_weather.head()
# Out:
#             date  DE_av_windspeed_ms_north  DE_percip_mm_north  \
# 48942 2015-01-01                  7.336364         -112.171429
# 48943 2015-01-02                 10.930303         -112.431429
# 48944 2015-01-03                  8.972727         -111.354286
# 48945 2015-01-04                  7.393939         -113.365714
# 48946 2015-01-05                  5.606061         -113.351429
#
#        DE_sun_hrs_north  DE_av_windspeed_ms_south  DE_percip_mm_south  \
# 48942          2.980412                  2.880556            0.065789
# 48943          0.984794                  5.925714            3.997368
# 48944          0.045118                  4.957143           14.647368
# 48945          3.463676                  4.774286            1.015789
# 48946          0.894176                  3.035294            0.168421
#
#        DE_sun_hrs_south  DK_sun_hrs  DK_av_windSpeed_ms  \
# 48942          2.053026         0.0                 8.4
# 48943          0.451316         2.0                12.0
# 48944          0.111895         2.5                 8.2
# 48945          1.045184         5.2                 6.0
# 48946          4.415789         0.3                 3.2
#
#        CZ_av_temperatureChange  CZ_av_windSpeed  FR_av_temperatureChange  \
# 48942                      NaN              NaN                      NaN
# 48943                      NaN              NaN                      NaN
# 48944                      NaN              NaN                      NaN
# 48945                      NaN              NaN                      NaN
# 48946                      NaN              NaN                      NaN
#
#        FR_av_windSpeed
# 48942              NaN
# 48943              NaN
# 48944              NaN
# 48945              NaN
# 48946              NaN

# %%
#make hourly
df_weather = bda_utilities.make_hourly(df_weather)

# %%
# Weather data for CZ and FR only start in 2017, so we drop them
df_weather.set_index("date").iloc[:,8:].plot()
df_weather = df_weather.drop(columns=df_weather.columns[8:])

# %%
# Percipitation has probably no effect on power flow, so we drop those as well 
df_weather = df_weather.drop(columns=[col for col in df_weather.columns if "percip" in col])

# %%
# DK sun hours has great portions of missing values, so we drop it . 
df_weather['DK_sun_hrs'].plot()
df_weather = df_weather.drop(columns=['DK_sun_hrs'])

# %% [markdown]
# Create a df containing a 24 lag for power flow values.

# %%
df_24h_lag = df.copy()
df_24h_lag.set_index("date", inplace=True)
df_24h_lag = df_24h_lag.shift(+24)

def custom_column_mapper(df, append_str):
    cols = df.columns
    mapper = {}
    for col in cols:
        mapper[col]=col + append_str
    return mapper

df_24h_lag.rename(columns=custom_column_mapper(df_24h_lag, "-24h"), inplace=True)
df_24h_lag.reset_index(inplace=True)
df_24h_lag.iloc[20:28]
# Out:
#                   date  NX-24h  NL-24h  CHE-24h  DNK-24h  CZE-24h  LUX-24h  \
# 20 2015-06-01 20:00:00     NaN     NaN      NaN      NaN      NaN      NaN
# 21 2015-06-01 21:00:00     NaN     NaN      NaN      NaN      NaN      NaN
# 22 2015-06-01 22:00:00     NaN     NaN      NaN      NaN      NaN      NaN
# 23 2015-06-01 23:00:00     NaN     NaN      NaN      NaN      NaN      NaN
# 24 2015-06-02 00:00:00  7279.0  3932.0    145.0   -272.0    554.0      0.0
# 25 2015-06-02 01:00:00  7167.0  4014.0    261.0   -141.0    469.0      0.0
# 26 2015-06-02 02:00:00  6667.0  3864.0    103.0   -326.0    422.0      0.0
# 27 2015-06-02 03:00:00  6413.0  4242.0     42.0   -262.0    235.0      0.0
#
#     SWE-24h  AUT-24h  FRA-24h  PL-24h
# 20      NaN      NaN      NaN     NaN
# 21      NaN      NaN      NaN     NaN
# 22      NaN      NaN      NaN     NaN
# 23      NaN      NaN      NaN     NaN
# 24      1.0   1394.0    246.0  1279.0
# 25      1.0   1355.0     66.0  1142.0
# 26      1.0   1574.0   -105.0  1134.0
# 27      1.0   1271.0   -206.0  1090.0

# %% [markdown]
# Import and format consumption data

# %%
df_consumption = preprocessing_trade_price_consumption.import_consumptionData()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-144f78d5023d> in <module>
# ----> 1 df_consumption = preprocessing_trade_price_consumption.import_consumptionData()
#
# ~\PycharmProjects\BDA\scripts\preprocessing_trade_price_consumption.py in import_consumptionData(path)
#     112         if i == 0:
#     113             df_consumption = pd.read_csv(files[i],
# --> 114                         sep=";",
#     115                         decimal=r",",
#     116                         thousands=r".",
#
# ~\PycharmProjects\BDA\scripts\preprocessing_trade_price_consumption.py in <dictcomp>(.0)
#     112         if i == 0:
#     113             df_consumption = pd.read_csv(files[i],
# --> 114                         sep=";",
#     115                         decimal=r",",
#     116                         thousands=r".",
#
# NameError: name 'numberparse' is not defined

# %%
df_planned_prod.head()
# Out:
#         date  FR_production_MW_planned  FR_production_MW_actual  \
# 0 2017-01-01              58367.062500             60671.125000
# 1 2017-01-02              63173.583333             65638.687500
# 2 2017-01-03              65237.541667             68084.437500
# 3 2017-01-04              64608.520833             67443.812500
# 4 2017-01-05              65933.500000             68893.145833
#
#    CZ_DE_sum_Trade_MW_actual  CZ_DE_sum_Trade_MW_planned  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    CZ_production_MW_planned  DE_production_MW_planned  DE_production_MW_actual
# 0                       NaN                 1335338.0               1298110.25
# 1                       NaN                 1822690.0               1695523.50
# 2                       NaN                 1794084.0               1605824.75
# 3                       NaN                 1363933.0               1207218.75
# 4                       NaN                 1404833.0               1279176.75

# %% [markdown]
# Make master dataframe containing all the information.

# %%
df_master = df.copy()
df_master = df_master.merge(df_24h_lag)
df_master = df_master.merge(df_weather)
df_master.head()
# Out:
#                  date      NX      NL    CHE    DNK    CZE  LUX  SWE     AUT  \
# 0 2015-06-01 00:00:00  7279.0  3932.0  145.0 -272.0  554.0  0.0  1.0  1394.0
# 1 2015-06-01 01:00:00  7167.0  4014.0  261.0 -141.0  469.0  0.0  1.0  1355.0
# 2 2015-06-01 02:00:00  6667.0  3864.0  103.0 -326.0  422.0  0.0  1.0  1574.0
# 3 2015-06-01 03:00:00  6413.0  4242.0   42.0 -262.0  235.0  0.0  1.0  1271.0
# 4 2015-06-01 04:00:00  5347.0  4292.0 -127.0 -582.0  161.0  0.0  1.0  1068.0
#
#      FRA  ...  CZE-24h  LUX-24h  SWE-24h  AUT-24h  FRA-24h  PL-24h  \
# 0  246.0  ...      NaN      NaN      NaN      NaN      NaN     NaN
# 1   66.0  ...      NaN      NaN      NaN      NaN      NaN     NaN
# 2 -105.0  ...      NaN      NaN      NaN      NaN      NaN     NaN
# 3 -206.0  ...      NaN      NaN      NaN      NaN      NaN     NaN
# 4 -549.0  ...      NaN      NaN      NaN      NaN      NaN     NaN
#
#    DE_av_windspeed_ms_north  DE_sun_hrs_north  DE_av_windspeed_ms_south  \
# 0                  4.535484          6.021697                      3.65
# 1                  4.535484          6.021697                      3.65
# 2                  4.535484          6.021697                      3.65
# 3                  4.535484          6.021697                      3.65
# 4                  4.535484          6.021697                      3.65
#
#    DE_sun_hrs_south
# 0          3.698263
# 1          3.698263
# 2          3.698263
# 3          3.698263
# 4          3.698263
#
# [5 rows x 25 columns]
